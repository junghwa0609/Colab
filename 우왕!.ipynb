# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/commit_with_colab
# Out:
# /content/drive/MyDrive/commit_with_colab

# %%
# !git clone https://junghwa0609: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@github.com/junghwa0609/Colab_truly_flower.git
# Out:
# Cloning into 'Colab_truly_flower'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (11/11), 4.10 KiB | 419.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
cd Colab_truly_flower
# Out:
# /content/drive/MyDrive/commit_with_colab/Colab_truly_flower

# %%
# !git config --global user.email 'hayan094666@gmail.com'
# !git config --global user.name 'junghwa0609'

# %%
# !git add 우왕!.ipynb
